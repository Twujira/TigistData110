# %% [markdown]
# <a href="https://colab.research.google.com/github/Twujira/TigistData110/blob/main/Project2_Japanquake.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Import necessary packages
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Load the dataset
url = "https://raw.githubusercontent.com/Twujira/TigistData110/main/Dataset/japan_quakes_01-18.csv"
Japanquake = pd.read_csv(url)
print(Japanquake.head())
# Out:
#                        time  latitude  longitude  depth  mag magType  nst  \
# 0  2018-11-27T14:34:20.900Z   48.3780   154.9620  35.00  4.9      mb  NaN
# 1  2018-11-26T23:33:50.630Z   36.0733   139.7830  48.82  4.8     mww  NaN
# 2  2018-11-26T13:04:02.250Z   38.8576   141.8384  50.56  4.5      mb  NaN
# 3  2018-11-26T05:20:16.440Z   50.0727   156.1420  66.34  4.6      mb  NaN
# 4  2018-11-25T09:19:05.010Z   33.9500   134.4942  38.19  4.6      mb  NaN
#
#      gap   dmin   rms  ...                   updated  \
# 0   92.0  5.044  0.63  ...  2018-11-27T16:06:33.040Z
# 1  113.0  1.359  1.13  ...  2018-11-27T16:44:22.223Z
# 2  145.0  1.286  0.84  ...  2018-11-26T23:52:21.074Z
# 3  128.0  3.191  0.62  ...  2018-11-26T08:13:58.040Z
# 4  104.0  0.558  0.61  ...  2018-11-25T23:24:52.615Z
#
#                                   place        type horizontalError  \
# 0  269km SSW of Severo-Kuril'sk, Russia  earthquake             7.6
# 1               3km SSW of Sakai, Japan  earthquake             6.0
# 2            26km SSE of Ofunato, Japan  earthquake             8.4
# 3     67km S of Severo-Kuril'sk, Russia  earthquake             9.7
# 4         9km SW of Komatsushima, Japan  earthquake             3.4
#
#   depthError  magError  magNst    status  locationSource magSource
# 0        1.7     0.036   248.0  reviewed              us        us
# 1        6.1     0.071    19.0  reviewed              us        us
# 2        9.5     0.156    12.0  reviewed              us        us
# 3        7.8     0.045   151.0  reviewed              us        us
# 4       10.1     0.132    17.0  reviewed              us        us
#
# [5 rows x 22 columns]

# %%
import folium

# %%
Japanquake.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14092 entries, 0 to 14091
# Data columns (total 22 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   time             14092 non-null  object
#  1   latitude         14092 non-null  float64
#  2   longitude        14092 non-null  float64
#  3   depth            14092 non-null  float64
#  4   mag              14092 non-null  float64
#  5   magType          14092 non-null  object
#  6   nst              10483 non-null  float64
#  7   gap              13310 non-null  float64
#  8   dmin             3607 non-null   float64
#  9   rms              14014 non-null  float64
#  10  net              14092 non-null  object
#  11  id               14092 non-null  object
#  12  updated          14092 non-null  object
#  13  place            14092 non-null  object
#  14  type             14092 non-null  object
#  15  horizontalError  2800 non-null   float64
#  16  depthError       9040 non-null   float64
#  17  magError         3431 non-null   float64
#  18  magNst           11048 non-null  float64
#  19  status           14092 non-null  object
#  20  locationSource   14092 non-null  object
#  21  magSource        14092 non-null  object
# dtypes: float64(12), object(10)
# memory usage: 2.4+ MB

# %%
Japanquake.describe()
# Out:
#            latitude     longitude         depth           mag           nst  \
# count  14092.000000  14092.000000  14092.000000  14092.000000  10483.000000
# mean      37.410294    142.980441     51.364838      4.817045    117.352094
# std        6.605873      6.552510     76.603810      0.378618    123.273889
# min       23.532900    124.293000      0.000000      4.500000      5.000000
# 25%       33.147675    141.071000     14.400000      4.600000     36.000000
# 50%       37.357000    142.452100     35.000000      4.700000     69.000000
# 75%       42.271325    144.432000     50.372500      4.900000    153.000000
# max       50.816100    158.818000    683.360000      9.100000    929.000000
#
#                 gap         dmin           rms  horizontalError   depthError  \
# count  13310.000000  3607.000000  14014.000000      2800.000000  9040.000000
# mean     104.272149     2.359796      0.876561         7.288607     7.822920
# std       37.893474     1.658681      0.203787         2.263028     5.861948
# min        8.000000     0.038000      0.120000         1.400000     0.000000
# 25%       78.000000     1.109000      0.740000         5.800000     4.400000
# 50%      112.700000     1.979000      0.850000         7.100000     6.200000
# 75%      130.900000     3.122500      0.990000         8.500000     9.600000
# max      306.600000    18.781000      1.880000        25.600000    70.700000
#
#           magError        magNst
# count  3431.000000  11048.000000
# mean      0.095182     48.590695
# std       0.060710     70.233727
# min       0.019000      1.000000
# 25%       0.054000      9.000000
# 50%       0.079000     23.000000
# 75%       0.118000     57.000000
# max       0.555000    941.000000

# %%
# Import necessary libraries
import pandas as pd

# Assuming JapanQuakes DataFrame is already loaded

# Convert the 'time' column to datetime format
Japanquake['time'] = pd.to_datetime(Japanquake['time'])

# Extract the year from the 'time' column and create a new column 'year'
Japanquake['year'] = Japanquake['time'].dt.year

# Filter the DataFrame to include only rows from the year 2011
filtered_JapanQuakes = Japanquake[Japanquake['year'] >= 2011]

# Display the first few rows of the filtered DataFrame
print(filtered_JapanQuakes.head())
print(filtered_JapanQuakes.tail())
# Out:
#                               time  latitude  longitude  depth  mag magType  \
# 0 2018-11-27 14:34:20.900000+00:00   48.3780   154.9620  35.00  4.9      mb
# 1 2018-11-26 23:33:50.630000+00:00   36.0733   139.7830  48.82  4.8     mww
# 2 2018-11-26 13:04:02.250000+00:00   38.8576   141.8384  50.56  4.5      mb
# 3 2018-11-26 05:20:16.440000+00:00   50.0727   156.1420  66.34  4.6      mb
# 4 2018-11-25 09:19:05.010000+00:00   33.9500   134.4942  38.19  4.6      mb
#
#    nst    gap   dmin   rms  ...                                 place  \
# 0  NaN   92.0  5.044  0.63  ...  269km SSW of Severo-Kuril'sk, Russia
# 1  NaN  113.0  1.359  1.13  ...               3km SSW of Sakai, Japan
# 2  NaN  145.0  1.286  0.84  ...            26km SSE of Ofunato, Japan
# 3  NaN  128.0  3.191  0.62  ...     67km S of Severo-Kuril'sk, Russia
# 4  NaN  104.0  0.558  0.61  ...         9km SW of Komatsushima, Japan
#
#          type horizontalError depthError magError  magNst    status  \
# 0  earthquake             7.6        1.7    0.036   248.0  reviewed
# 1  earthquake             6.0        6.1    0.071    19.0  reviewed
# 2  earthquake             8.4        9.5    0.156    12.0  reviewed
# 3  earthquake             9.7        7.8    0.045   151.0  reviewed
# 4  earthquake             3.4       10.1    0.132    17.0  reviewed
#
#    locationSource  magSource  year
# 0              us         us  2018
# 1              us         us  2018
# 2              us         us  2018
# 3              us         us  2018
# 4              us         us  2018
#
# [5 rows x 23 columns]
#                                  time  latitude  longitude  depth  mag  \
# 8892 2011-01-02 07:04:49.360000+00:00    27.014    143.671   10.0  4.9
# 8893 2011-01-01 17:57:31.940000+00:00    27.136    143.518   10.0  4.5
# 8894 2011-01-01 17:51:00.820000+00:00    27.139    143.511   10.0  4.6
# 8895 2011-01-01 15:34:34.490000+00:00    37.802    138.918  173.0  4.5
# 8896 2011-01-01 00:02:31.960000+00:00    27.247    143.166   10.0  5.0
#
#      magType   nst    gap  dmin   rms  ...  \
# 8892      mb  85.0  102.7   NaN  0.87  ...
# 8893      mb  41.0   77.0   NaN  0.94  ...
# 8894      mb  18.0  115.0   NaN  1.21  ...
# 8895      mb  31.0  125.5   NaN  0.85  ...
# 8896      mb  96.0   48.7   NaN  0.96  ...
#
#                                      place        type horizontalError  \
# 8892           Bonin Islands, Japan region  earthquake             NaN
# 8893           Bonin Islands, Japan region  earthquake             NaN
# 8894           Bonin Islands, Japan region  earthquake             NaN
# 8895  near the west coast of Honshu, Japan  earthquake             NaN
# 8896           Bonin Islands, Japan region  earthquake             NaN
#
#      depthError magError  magNst    status  locationSource  magSource  year
# 8892        NaN      NaN    33.0  reviewed              us         us  2011
# 8893        NaN      NaN     9.0  reviewed              us         us  2011
# 8894        NaN      NaN     2.0  reviewed              us         us  2011
# 8895        5.7      NaN     7.0  reviewed              us         us  2011
# 8896        NaN      NaN    49.0  reviewed              us         us  2011
#
# [5 rows x 23 columns]

# %%
filtered_JapanQuakes.describe()
# Out:
#           latitude    longitude        depth          mag          nst  \
# count  8897.000000  8897.000000  8897.000000  8897.000000  5289.000000
# mean     36.649455   141.973222    46.098752     4.797044   117.821327
# std       5.533366     5.386822    64.509261     0.355186   121.593236
# min      23.532900   124.394000     0.000000     4.500000     7.000000
# 25%      34.631000   141.092000    17.900000     4.600000    38.000000
# 50%      37.140300   142.233400    35.000000     4.700000    68.000000
# 75%      39.117000   143.603000    48.070000     4.900000   154.000000
# max      50.816100   158.818000   683.360000     9.100000   918.000000
#
#                gap         dmin          rms  horizontalError   depthError  \
# count  8896.000000  3607.000000  8897.000000      2800.000000  7356.000000
# mean    102.591805     2.359796     0.860200         7.288607     7.273056
# std      37.979447     1.658681     0.208857         2.263028     5.273566
# min       8.000000     0.038000     0.120000         1.400000     0.000000
# 25%      74.500000     1.109000     0.720000         5.800000     4.200000
# 50%     112.000000     1.979000     0.840000         7.100000     5.900000
# 75%     129.400000     3.122500     0.980000         8.500000     8.700000
# max     277.000000    18.781000     1.880000        25.600000    62.300000
#
#           magError       magNst         year
# count  3431.000000  7792.000000  8897.000000
# mean      0.095182    58.273614  2013.067776
# std       0.060710    79.501698     2.349808
# min       0.019000     1.000000  2011.000000
# 25%       0.054000    11.000000  2011.000000
# 50%       0.079000    27.000000  2012.000000
# 75%       0.118000    72.000000  2015.000000
# max       0.555000   941.000000  2018.000000

# %%
# Create a histogram for the 'mag' column
plt.figure(figsize=(6, 4))
sns.histplot(data=filtered_JapanQuakes, x='mag' ,bins=10, color='orange', alpha=1)

# Add labels and title
plt.xlabel('Magnitude')
plt.ylabel('Frequency')
plt.title('Histogram of Magnitude')

# Display the plot
plt.show()

# %%
# Boxplot of magnitude by corresponding type
plt.figure(figsize=(6, 4))
sns.boxplot(x='magType', y='mag', data=filtered_JapanQuakes)

# Add labels and title
plt.xlabel('magType')
plt.ylabel('Magnitude')
plt.title('Box Plot of Magnitude by magType')
plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.boxplot(x='magType', y='rms', data=filtered_JapanQuakes)

# Add labels and title
plt.xlabel('magType')
plt.ylabel('RMS')
plt.title('Box Plot of RMS by magType')
plt.show()

# %%
High_quake = filtered_JapanQuakes[(filtered_JapanQuakes['mag'] > 6.0)]
print(High_quake.shape)
# Out:
# (125, 23)

# %%
Quake_Group=filtered_JapanQuakes.groupby(['magType','year']).size().reset_index(name='frequency')

Quake_Group
# Out:
#    magType  year  frequency
# 0       mb  2011       3298
# 1       mb  2012       1019
# 2       mb  2013        666
# 3       mb  2014        701
# 4       mb  2015        582
# 5       mb  2016        654
# 6       mb  2017        427
# 7       mb  2018        475
# 8       ms  2011          4
# 9      mwb  2011         39
# 10     mwb  2012         21
# 11     mwb  2013         27
# 12     mwb  2014         15
# 13     mwb  2015          7
# 14     mwb  2018          1
# 15     mwc  2011        383
# 16     mwc  2012         13
# 17     mwc  2013          3
# 18     mwc  2015          2
# 19     mwr  2011          2
# 20     mwr  2013          2
# 21     mwr  2014          4
# 22     mwr  2015         31
# 23     mwr  2016         31
# 24     mwr  2017         18
# 25     mwr  2018         15
# 26     mww  2011         85
# 27     mww  2012         33
# 28     mww  2013         26
# 29     mww  2014         31
# 30     mww  2015         44
# 31     mww  2016         87
# 32     mww  2017         78
# 33     mww  2018         73

# %%
year_counts = filtered_JapanQuakes['year'].value_counts()
year_counts
# Out:
# year
# 2011    3811
# 2012    1086
# 2016     772
# 2014     751
# 2013     724
# 2015     666
# 2018     564
# 2017     523
# Name: count, dtype: int64

# %%
#Plot of number earthquakes each year
plt.figure(figsize=(6, 4))
sns.barplot(x=year_counts.index, y=year_counts.values, palette='viridis')

# Add labels and title
plt.xlabel('Year')
plt.ylabel('Number of Earthquakes')
plt.title('Number of Earthquakes per Year')

# Display the plot
plt.show()
# Out:
# <ipython-input-105-050ca47d718d>:3: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %%
MagType_counts = filtered_JapanQuakes['magType'].value_counts()
MagType_counts
# Out:
# magType
# mb     7822
# mww     457
# mwc     401
# mwb     110
# mwr     103
# ms        4
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10, 6))
plt.scatter(filtered_JapanQuakes['mag'],filtered_JapanQuakes['depth'])
# Add labels and title
plt.xlabel('Magnitude')
plt.ylabel('Depth')
plt.title('Scatter Plot of Depth vs Magnitude')
plt.show()

# %% [markdown]
# Magnitude and depth have very weak correlation. as we can see in the correlation heat map below, the correlation of magnitude and depth is 0.07.

# %%
# Select only the specified columns from the DataFrame
columns_new = ['latitude', 'longitude', 'depth', 'mag','gap','rms']

# Filter the DataFrame to include only the specified columns
filtered_JapanQuakes = filtered_JapanQuakes[columns_new]

# Calculate the correlation matrix for the selected numeric features
corr_matrix = filtered_JapanQuakes.corr()

# Set up the figure size
plt.figure(figsize=(8, 6))

# Visualize the correlation matrix using a heatmap
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)

# Add a title
plt.title('Correlation Matrix of Selected Features')

# Show the plot
plt.show()

# %%
import plotly.express as px
# Drop rows with missing or invalid values in the 'latitude' and 'longitude' columns
filtered_JapanQuakes = filtered_JapanQuakes.dropna(subset=['latitude', 'longitude'])

# Create a simple scatter map
fig = px.scatter_geo(filtered_JapanQuakes, lat='latitude', lon='longitude',
                     title='Japan Earthquake Map')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="a08b146d-b087-4094-b205-a7fdbf4c9234" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a08b146d-b087-4094-b205-a7fdbf4c9234")) {                    Plotly.newPlot(                        "a08b146d-b087-4094-b205-a7fdbf4c9234",                        [{"geo":"geo","hovertemplate":"latitude=%{lat}\u003cbr\u003elongitude=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","lat":[48.378,36.0733,38.8576,50.0727,33.95,48.4158,37.1821,29.3424,44.4524,30.4087,42.0009,24.1937,30.7822,25.3931,26.3407,39.6014,42.6765,34.7663,45.2679,42.9554,31.4232,49.5372,31.4465,31.4081,44.7104,40.7338,46.4029,31.3464,29.2926,29.2376,29.2918,44.4808,33.6271,44.5643,41.8346,36.3247,47.8166,33.689,43.8269,42.3089,31.7203,32.0275,36.4974,31.6133,36.9038,37.1874,29.7245,40.1961,36.9011,31.1987,44.6221,44.4503,44.5381,38.3158,37.339,38.3475,37.8031,37.5957,28.9647,35.1704,49.3746,37.0022,42.3707,33.5493,38.4427,32.0877,47.0156,35.5209,29.1271,25.947,25.856,41.6267,38.6914,47.4724,49.3095,25.9629,32.6162,26.5525,38.2959,25.8498,27.8272,26.3139,39.3602,49.3107,47.1406,49.1822,47.8596,35.7549,42.6212,48.3694,49.2456,27.9648,49.1973,49.2508,49.2243,49.3443,49.3262,49.4323,49.1392,49.2,49.1265,49.2902,39.0221,44.2535,49.4001,49.3959,41.0022,27.9703,29.9016,45.8362,37.3655,28.4707,44.5672,23.6085,23.5895,42.6258,23.6221,23.7133,26.5339,35.0158,26.4868,42.6914,32.6447,26.7298,42.5988,26.6068,31.0932,35.7891,41.1356,37.6683,38.9592,26.7516,42.893,31.9167,42.5471,42.7652,47.1412,37.148,26.7884,47.6007,45.1476,27.4408,44.7214,48.1944,41.9449,25.0248,45.94,36.4966,35.2249,26.6637,45.2211,45.1727,26.7341,26.6747,39.8823,35.7288,38.4621,26.7882,36.0211,26.6887,47.2515,26.7095,42.6789,26.655,24.1515,26.7024,35.3801,26.7178,26.6213,26.4878,26.5742,49.8508,26.6904,26.6617,26.7462,26.6846,26.6666,26.5998,26.6092,26.6318,26.6827,26.7366,26.774,26.5723,26.707,26.6796,26.6176,26.6974,26.6969,26.6719,44.408,26.7476,26.7059,26.7302,36.8176,42.7494,42.634,45.6083,30.4041,30.3898,41.2526,39.6445,30.4666,42.6802,34.9969,42.785,29.8659,30.5852,29.7361,42.7949,42.7397,42.7233,42.7449,42.6827,42.681,42.7136,42.7504,42.7676,42.59,42.6389,42.6861,43.3596,36.4802,34.5324,29.1934,29.4436,27.9555,36.0507,36.9765,43.8089,40.9248,25.5728,45.8152,45.9541,44.0629,49.972,44.1905,44.0472,44.1767,44.1254,44.2437,44.1046,44.228,44.2579,24.3515,40.558,41.1252,37.7816,23.6691,41.4025,32.7493,25.2181,32.819,35.9798,23.5611,38.5316,25.5288,23.5491,48.1469,23.6396,23.573,44.6762,44.7627,23.5329,23.6965,23.5356,44.2389,34.7762,25.415,35.1535,43.9569,43.3682,30.5992,25.7988,48.2834,41.9949,35.2408,37.2213,48.4593,47.6279,43.1454,29.2356,44.2631,44.3262,44.1651,37.2137,44.2656,44.622,44.2879,37.8857,44.278,35.503,35.5093,40.2263,41.5086,30.3775,44.3454,50.3103,46.4407,44.5287,37.1788,47.0404,47.6266,45.7269,45.7361,49.6567,45.5105,36.9244,30.6506,45.3744,26.2655,37.5147,46.6511,25.3772,25.931,45.1211,27.1198,37.1264,35.7832,31.3888,45.6859,43.576,36.4826,36.4291,35.4722,42.2875,24.0126,32.0106,38.2054,23.5464,23.5443,36.2748,36.2766,41.563,32.2573,35.1702,27.8968,35.1073,48.3412,29.3529,32.4682,41.2557,29.904,46.9633,41.5109,34.9902,48.4187,39.336,34.8713,29.1628,29.0425,43.6068,41.2924,34.788,34.8246,42.746,38.7988,36.5135,35.2647,35.5812,30.078,50.5863,42.5704,35.1148,31.3566,31.295,30.4455,27.2865,43.8243,35.7724,35.7961,36.5547,29.9426,27.602,35.5395,43.8343,43.9796,45.2293,28.9869,36.2643,48.2736,38.3019,28.483,45.2355,37.8709,27.5625,36.9333,26.4017,25.5048,27.7142,41.2337,47.3129,35.6324,46.4458,45.3113,42.6846,35.6584,28.3377,35.5025,40.0942,27.0795,38.4847,42.5367,36.643,32.3715,23.9972,27.8913,26.7001,29.7665,37.8161,39.6737,31.4438,28.4902,40.1271,37.1582,30.6642,35.6104,46.5296,46.6033,44.7 ...
